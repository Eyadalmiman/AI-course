# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import simplejson
import random
from scipy import stats
from pathlib import Path
from typing import List, Dict, Tuple

# %% [markdown]
# **Code**

# %%
def softmax_stable(x):
    shift_x = x - np.max(x)
    exps = np.exp(shift_x)
    return exps / np.sum(exps)

samples = 100
features = 4
classes = 3

X = np.random.normal(loc = 0, scale = 1, size = (samples, features))

true_labels = np.random.randint(0, classes, size = samples)

W = np.random.randn(features, classes)
b = np.random.randn(classes)

logits = np.dot(X, W) + b
probabilities = softmax_stable(logits)

predictions = np.argmax(probabilities, axis = 1)
accuracy = np.mean(predictions == true_labels)

correct_class_probs = probabilities[np.arange(samples), true_labels]
loss = -np.mean(np.log(correct_class_probs + 1e-9))

print(f"Sample predictions ; {predictions[:10]}")
print(f"Accuracy : {accuracy * 100:.2f}%")
print(f"Average loss : {loss:.4f}")
# Out:
# Sample predictions ; [2 2 2 1 2 1 1 1 1 1]
# Accuracy : 30.00%
# Average loss : 6.4102
