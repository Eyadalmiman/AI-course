# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import simplejson
from pathlib import Path
from typing import List, Dict, Tuple

# %% [markdown]
# **Code**

# %%
df = pd.read_csv("Data/day35_project.csv")

# %% [markdown]
# **Univariate analysis**

# %%
print(df.head())
print(df.info())
plt.figure(figsize=(8,5))
sns.histplot(df["age"], kde = True)
plt.title("age col")
plt.show()
plt.figure(figsize=(8,5))
sns.boxplot(df["income"])
plt.title("income col")
plt.show()
plt.figure(figsize=(8,5))
sns.kdeplot(df["spend"], fill = True)
plt.title("spend col")
plt.show()
# Out:
#    age  income  spend segment
# 0   25   50000   2000       A
# 1   40   80000   4000       B
# 2   35   65000   3500       A
# 3   50  120000   6000       C
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      4 non-null      int64
#  1   income   4 non-null      int64
#  2   spend    4 non-null      int64
#  3   segment  4 non-null      object
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
# None

# %% [markdown]
# **Bivariate**

# %%
plt.figure(figsize = (8,5))
sns.scatterplot(data = df, x = "spend", y = "income", hue = "segment")
plt.title("scatterplot")
plt.show()
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', vmin = -1, vmax = 1)
plt.title("heatmap")
plt.show()
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='segment', hue = "segment")
plt.title("countplot")
plt.show()

# %% [markdown]
# **Correlation**

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(data=corr, cmap="coolwarm", vmin=-1, vmax=1, annot=True)
plt.title("correlation heatmap")
print(f"correlation :\n{corr}")
# Out:
# correlation :
#              age    income     spend
# age     1.000000  0.970748  0.993520
# income  0.970748  1.000000  0.984436
# spend   0.993520  0.984436  1.000000
