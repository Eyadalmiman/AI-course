# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
import simplejson
import os
import time
import matplotlib.pyplot as plt
from pathlib import Path
from typing import List, Dict, Tuple
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# **Code**

# %%
df = pd.read_csv("day16_encoding.csv")
le_df = LabelEncoder()
df["city"] = le_df.fit_transform(df["city"])
df_ohe = pd.get_dummies(df, columns = ["city"], prefix = "city")
print("Classes", le_df.classes_)
print("One hot encoding\n", df_ohe.head())
print(df[["city", "membership", "purchases"]])
# Out:
# Classes ['CHI' 'LA' 'NY' 'SF']
# One hot encoding
#    membership  purchases  city_0  city_1  city_2  city_3
# 0     bronze          3   False   False    True   False
# 1     silver          5   False   False   False    True
# 2       gold          1   False    True   False   False
# 3     bronze          2    True   False   False   False
#    city membership  purchases
# 0     2     bronze          3
# 1     3     silver          5
# 2     1       gold          1
# 3     0     bronze          2
