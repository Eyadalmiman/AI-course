# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Read in the data from the CSV file
url="https://raw.githubusercontent.com/oreilly-mlsec/book-resources/refs/heads/master/chapter2/datasets/payment_fraud.csv"
df = pd.read_csv(url)

# %%
df.sample(30)
# Out:
#        accountAgeDays  numItems  localTime paymentMethod  \
# 6840             1480         1   4.886641        paypal
# 2202             1197         1   4.505662    creditcard
# 1069              187         1   4.921318    creditcard
# 16930             666         1   4.921318    creditcard
# 7335              995         1   4.524580    creditcard
# 26179            2000         1   4.921349    creditcard
# 29631             853         1   5.034622    creditcard
# 25358              34         1   4.962055    creditcard
# 3703             1623         1   2.596228        paypal
# 3279             2000         1   4.895263        paypal
# 23915              17         1   4.921318    creditcard
# 30225            1495         1   4.505662    creditcard
# 30696            2000         1   5.040929    creditcard
# 38210            2000         1   4.895263        paypal
# 11225             107         1   4.886641    creditcard
# ...

# %%
# Convert categorical feature into dummy variables with one-hot encoding
df = pd.get_dummies(df, columns=['paymentMethod'])
df.sample(3)
# Out:
#        accountAgeDays  numItems  localTime  paymentMethodAgeDays  label  \
# 592              2000         1   4.836982              0.000000      0
# 24980            2000         1   3.575983              0.020139      0
# 14596             668         1   4.748314              0.000000      0
#
#        paymentMethod_creditcard  paymentMethod_paypal  \
# 592                       False                 False
# 24980                      True                 False
# 14596                      True                 False
#
#        paymentMethod_storecredit
# 592                         True
# 24980                      False
# 14596                      False

# %%
# Split dataset up into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('label', axis=1), df['label'],
    test_size=0.33, random_state=17)

# %%
# Initialize and train classifier model
clf = LogisticRegression().fit(X_train, y_train)

# Make predictions on test set
y_pred = clf.predict(X_test)

# %%
# Compare test set predictions with ground truth labels
print(accuracy_score(y_pred, y_test))
print(confusion_matrix(y_test, y_pred))
# Out:
# 1.0
# [[12753     0]
#  [    0   190]]
